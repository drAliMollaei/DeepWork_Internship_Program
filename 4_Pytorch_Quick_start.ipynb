# %% [markdown]
# # New section

# %%
# https://pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:02<00:00, 9770590.36it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 183499.87it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3289497.37it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 19108209.73it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %%
type(training_data)
# Out:
# torchvision.datasets.mnist.FashionMNIST

# %%
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
test_data
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 10000
#     Root location: data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader  = DataLoader(test_data,     batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %%
# Get cpu, gpu or mps device for training.
device = ( "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu" )
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        #super().__init__(), nitialize the parent class and set up the structure of the neural network model.
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
                                                nn.Linear(28*28, 512),
                                                nn.ReLU(),
                                                nn.Linear(512, 512),
                                                nn.ReLU(),
                                                nn.Linear(512, 10)
        )
    # forward function,automatically executed when input data is passed to the model.
    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        # Perform the forward pass
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}] Details => batch+1 : {batch+1} , len(x):{len(X)}")

# loss: 1.900649  [57664/60000]

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.309888  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 2.295738  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 2.275672  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 2.263523  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 2.251365  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 2.221894  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 2.231804  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 2.195577  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 2.186020  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 2.163070  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 44.3%, Avg loss: 2.150129
#
# Epoch 2
# -------------------------------
# loss: 2.164692  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 2.150768  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 2.092063  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 2.105922  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 2.057578  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 1.995454  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 2.027429  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 1.942500  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 1.946385  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 1.887460  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 54.5%, Avg loss: 1.873885
#
# Epoch 3
# -------------------------------
# loss: 1.907227  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 1.876824  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 1.760848  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 1.802614  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 1.696924  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 1.648313  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 1.676137  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 1.573038  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 1.601744  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 1.508597  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 59.5%, Avg loss: 1.514663
#
# Epoch 4
# -------------------------------
# loss: 1.582291  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 1.548055  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 1.404003  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 1.471521  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 1.356641  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 1.353391  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 1.370919  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 1.293154  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 1.327033  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 1.238577  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 62.9%, Avg loss: 1.255220
#
# Epoch 5
# -------------------------------
# loss: 1.332891  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 1.312661  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 1.157550  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 1.254059  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 1.131053  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 1.159976  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 1.181092  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 1.117660  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 1.152431  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 1.078813  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 64.5%, Avg loss: 1.091814
#
# Epoch 6
# -------------------------------
# loss: 1.164799  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 1.160068  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 0.992106  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 1.116068  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 0.990801  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 1.027554  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 1.060765  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 1.003590  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 1.038443  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 0.977412  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.985048
#
# Epoch 7
# -------------------------------
# loss: 1.046611  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 1.058655  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 0.877191  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 1.024001  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 0.902366  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 0.932862  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 0.980582  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 0.928045  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 0.959943  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 0.909757  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 66.6%, Avg loss: 0.912135
#
# Epoch 8
# -------------------------------
# loss: 0.959466  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 0.987773  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 0.794645  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 0.959452  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 0.843806  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 0.863283  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 0.923719  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 0.877034  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 0.904049  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 0.861761  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 67.8%, Avg loss: 0.859996
#
# Epoch 9
# -------------------------------
# loss: 0.892548  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 0.935192  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 0.733156  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 0.912089  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 0.802630  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 0.811102  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 0.880670  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 0.841156  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 0.862632  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 0.825596  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 68.9%, Avg loss: 0.820873
#
# Epoch 10
# -------------------------------
# loss: 0.839231  [   64/60000] Details => batch+1 : 1 , len(x):64
# loss: 0.893892  [ 6464/60000] Details => batch+1 : 101 , len(x):64
# loss: 0.685488  [12864/60000] Details => batch+1 : 201 , len(x):64
# loss: 0.875929  [19264/60000] Details => batch+1 : 301 , len(x):64
# loss: 0.771840  [25664/60000] Details => batch+1 : 401 , len(x):64
# loss: 0.771202  [32064/60000] Details => batch+1 : 501 , len(x):64
# loss: 0.846244  [38464/60000] Details => batch+1 : 601 , len(x):64
# loss: 0.814589  [44864/60000] Details => batch+1 : 701 , len(x):64
# loss: 0.830650  [51264/60000] Details => batch+1 : 801 , len(x):64
# loss: 0.797091  [57664/60000] Details => batch+1 : 901 , len(x):64
# Test Error:
#  Accuracy: 70.2%, Avg loss: 0.790082
#
# Done!

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %%
print(device)
# Out:
# cuda

# %%
model = NeuralNetwork().to(device)
model.load_state_dict(torch.load("model.pth"))
# Out:
# <All keys matched successfully>

# %%
classes = [     "T-shirt/top",     "Trouser",     "Pullover",
    "Dress",     "Coat",     "Sandal",     "Shirt",
    "Sneaker",     "Bag",     "Ankle boot", ]

model.eval()
x, y = test_data[0][0], test_data[0][1]
with torch.no_grad():
    x = x.to(device)
    print(x)
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0118, 0.0039, 0.0000, 0.0000, 0.0275,
#           0.0000, 0.1451, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0078, 0.0000,
#           0.1059, 0.3294, 0.0431, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.4667, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.3451, 0.5608, 0.4314, 0.0000, 0.0000, 0.0000, 0.0000, 0.0863,
#           0.3647, 0.4157, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0157, 0.0000, 0.2078,
#           0.5059, 0.4706, 0.5765, 0.6863, 0.6157, 0.6510, 0.5294, 0.6039,
#           0.6588, 0.5490, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0078, 0.0000, 0.0431, 0.5373,
#           0.5098, 0.5020, 0.6275, 0.6902, 0.6235, 0.6549, 0.6980, 0.5843,
#           0.5922, 0.5647, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000,
#           0.0078, 0.0039, 0.0000, 0.0118, 0.0000, 0.0000, 0.4510, 0.4471,
#           0.4157, 0.5373, 0.6588, 0.6000, 0.6118, 0.6471, 0.6549, 0.5608,
#           0.6157, 0.6196, 0.0431, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0118, 0.0000, 0.0000, 0.3490, 0.5451, 0.3529,
#           0.3686, 0.6000, 0.5843, 0.5137, 0.5922, 0.6627, 0.6745, 0.5608,
#           0.6235, 0.6627, 0.1882, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0078, 0.0157,
#           0.0039, 0.0000, 0.0000, 0.0000, 0.3843, 0.5333, 0.4314, 0.4275,
#           0.4314, 0.6353, 0.5294, 0.5647, 0.5843, 0.6235, 0.6549, 0.5647,
#           0.6196, 0.6627, 0.4667, 0.0000],
#          [0.0000, 0.0000, 0.0078, 0.0078, 0.0039, 0.0078, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.1020, 0.4235, 0.4588, 0.3882, 0.4353, 0.4588,
#           0.5333, 0.6118, 0.5255, 0.6039, 0.6039, 0.6118, 0.6275, 0.5529,
#           0.5765, 0.6118, 0.6980, 0.0000],
#          [0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0824,
#           0.2078, 0.3608, 0.4588, 0.4353, 0.4039, 0.4510, 0.5059, 0.5255,
#           0.5608, 0.6039, 0.6471, 0.6667, 0.6039, 0.5922, 0.6039, 0.5608,
#           0.5412, 0.5882, 0.6471, 0.1686],
#          [0.0000, 0.0000, 0.0902, 0.2118, 0.2549, 0.2980, 0.3333, 0.4627,
#           0.5020, 0.4824, 0.4353, 0.4431, 0.4627, 0.4980, 0.4902, 0.5451,
#           0.5216, 0.5333, 0.6275, 0.5490, 0.6078, 0.6314, 0.5647, 0.6078,
#           0.6745, 0.6314, 0.7412, 0.2431],
#          [0.0000, 0.2667, 0.3686, 0.3529, 0.4353, 0.4471, 0.4353, 0.4471,
#           0.4510, 0.4980, 0.5294, 0.5333, 0.5608, 0.4941, 0.4980, 0.5922,
#           0.6039, 0.5608, 0.5804, 0.4902, 0.6353, 0.6353, 0.5647, 0.5412,
#           0.6000, 0.6353, 0.7686, 0.2275],
#          [0.2745, 0.6627, 0.5059, 0.4078, 0.3843, 0.3922, 0.3686, 0.3804,
#           0.3843, 0.4000, 0.4235, 0.4157, 0.4667, 0.4706, 0.5059, 0.5843,
#           0.6118, 0.6549, 0.7451, 0.7451, 0.7686, 0.7765, 0.7765, 0.7333,
#           0.7725, 0.7412, 0.7216, 0.1412],
#          [0.0627, 0.4941, 0.6706, 0.7373, 0.7373, 0.7216, 0.6706, 0.6000,
#           0.5294, 0.4706, 0.4941, 0.4980, 0.5725, 0.7255, 0.7647, 0.8196,
#           0.8157, 1.0000, 0.8196, 0.6941, 0.9608, 0.9882, 0.9843, 0.9843,
#           0.9686, 0.8627, 0.8078, 0.1922],
#          [0.0000, 0.0000, 0.0000, 0.0471, 0.2627, 0.4157, 0.6431, 0.7255,
#           0.7804, 0.8235, 0.8275, 0.8235, 0.8157, 0.7451, 0.5882, 0.3216,
#           0.0314, 0.0000, 0.0000, 0.0000, 0.6980, 0.8157, 0.7373, 0.6863,
#           0.6353, 0.6196, 0.5922, 0.0431],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]], device='cuda:0')
# Predicted: "Ankle boot", Actual: "Ankle boot"

# %%
import matplotlib.pyplot as plt
print(f'Predicted: "{predicted}", Actual: "{actual}"')
print(x.to('cpu').squeeze().size())
plt.imshow(x.to('cpu').squeeze(), cmap="gray")
plt.show()
# Out:
# Predicted: "Ankle boot", Actual: "Ankle boot"
# torch.Size([28, 28])

# %%
28*28
# Out:
# 784
